# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms import bipartite
import os
import json
from collections import Counter

# %% [markdown]
# ## Read Node Data

# %% [markdown]
# ### Repo Node

# %%
repo_path = 'repo_info'
repos = os.listdir(repo_path)
for file in repos:
    if not file.endswith('.json'):
        repos.remove(file)
    if file == '00_repo_names.json':
        repos.remove(file)

# %%
repos
# Out:
# ['100-Days-Of-ML-Code.json',
#  'AI-Expert-Roadmap.json',
#  'AI-For-Beginners.json',
#  'annotated_deep_learning_paper_implementations.json',
#  'applied-ml.json',
#  'awesome-datascience.json',
#  'awesome-deep-learning-papers.json',
#  'caffe.json',
#  'ColossalAI.json',
#  'cs-video-courses.json',
#  'd2l-zh.json',
#  'data-science-ipython-notebooks.json',
#  'Deep-Learning-Papers-Reading-Roadmap.json',
#  'DeepFaceLab.json',
#  'DeepSpeech.json',
#  'DeepSpeed.json',
#  'faceswap.json',
#  'fastai.json',
#  'GFPGAN.json',
#  'gradio.json',
#  'handson-ml.json',
#  'keras.json',
#  'machine-learning-for-software-engineers.json',
#  'Made-With-ML.json',
#  'mediapipe.json',
#  'ML-From-Scratch.json',
#  'MockingBird.json',
#  'netron.json',
#  'opencv.json',
#  'openpose.json',
#  'paper-reading.json',
#  'Prompt-Engineering-Guide.json',
#  'pytorch-lightning.json',
#  'pytorch-tutorial.json',
#  'pytorch.json',
#  'ray.json',
#  'Real-Time-Voice-Cloning.json',
#  'so-vits-svc.json',
#  'spaCy.json',
#  'spleeter.json',
#  'stable-diffusion-webui.json',
#  'stanford_alpaca.json',
#  'streamlit.json',
#  'TensorFlow-Examples.json',
#  'tensorflow.json',
#  'tesseract.js.json',
#  'transformers.json',
#  'TTS.json',
#  'ultralytics.json',
#  'yolov5.json']

# %% [markdown]
# ### User Node

# %%
starer_path = 'starer_info'
starers_file = os.listdir(starer_path)

# %%
edges = []
users = set()
for fileName in starers_file:
    with open(starer_path + '/' + fileName, 'r') as f:
        data = json.load(f)
        print(fileName)

        for user in data:
            id = user['username']
            edges.append((id, fileName))
            if fileName not in repos:
                print(fileName)
                print(id)
            users.add(id)
# Out:
# 100-Days-Of-ML-Code.json
# AI-Expert-Roadmap.json
# AI-For-Beginners.json
# annotated_deep_learning_paper_implementations.json
# applied-ml.json
# awesome-datascience.json
# awesome-deep-learning-papers.json
# caffe.json
# ColossalAI.json
# cs-video-courses.json
# d2l-zh.json
# data-science-ipython-notebooks.json
# Deep-Learning-Papers-Reading-Roadmap.json
# DeepFaceLab.json
# DeepSpeech.json
# DeepSpeed.json
# faceswap.json
# fastai.json
# GFPGAN.json
# gradio.json
# handson-ml.json
# keras.json
# machine-learning-for-software-engineers.json
# Made-With-ML.json
# mediapipe.json
# ML-From-Scratch.json
# MockingBird.json
# netron.json
# opencv.json
# openpose.json
# paper-reading.json
# Prompt-Engineering-Guide.json
# pytorch-lightning.json
# pytorch-tutorial.json
# pytorch.json
# ray.json
# Real-Time-Voice-Cloning.json
# so-vits-svc.json
# spaCy.json
# spleeter.json
# stable-diffusion-webui.json
# stanford_alpaca.json
# streamlit.json
# TensorFlow-Examples.json
# tensorflow.json
# tesseract.js.json
# transformers.json
# TTS.json
# ultralytics.json
# yolov5.json

# %%
len(users)
# Out:
# 799030

# %% [markdown]
# ## Construct Graph

# %%
B = nx.Graph()

B.add_nodes_from(repos, bipartite=0)
B.add_nodes_from(users, bipartite=1)

B.add_edges_from(edges)

# %%
degree_sequence = sorted((d for n, d in B.degree()), reverse=True)
dmax = max(degree_sequence)

fig = plt.figure("Degree of the graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

# ax0 = fig.add_subplot(axgrid[0:3, :])
# Gcc = B.subgraph(sorted(nx.connected_components(B), key=len, reverse=True)[0])
# pos = nx.spring_layout(Gcc, seed=10396953)
# nx.draw_networkx_nodes(Gcc, pos, ax=ax0, node_size=20)
# nx.draw_networkx_edges(Gcc, pos, ax=ax0, alpha=0.4)
# ax0.set_title("Connected components of G")
# ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2])
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:])
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

# fig.tight_layout()
plt.show()

# %%
A = bipartite.biadjacency_matrix(B, repos)

# %%
with open('adjacency_matrix.json', 'w+') as f:
    json.dump(A.todense().tolist(), f)

# %%
C = bipartite.biadjacency_matrix(B, users)

# %%
degX, degY = bipartite.degrees(B, repos)

# %%
dict(degX)
# Out:
# {'mychamli': 5,
#  'dywxzls': 1,
#  'thel3onardo': 1,
#  'lsaint': 1,
#  'jaime-cespedes-sisniega': 6,
#  'gbarnow': 3,
#  'JJJJood': 1,
#  'Leo-o333': 2,
#  'sovietspaceship2': 1,
#  'umleric': 1,
#  'elenderg': 1,
#  'bhismafarhan': 2,
#  'Huntersjm': 2,
#  'bankly': 1,
#  'Hang-CDLab': 1,
#  'MauricioMarlon': 1,
#  'pdtgct': 6,
#  'kldtz': 1,
#  'likeyuri': 1,
#  'pennywisdom': 1,
#  'sirguys': 1,
#  'Lilysunstrider': 1,
#  'SRatna': 2,
#  'bominkm': 1,
#  'nirved5': 1,
#  'Warsongs': 1,
#  'GGhuaxina': 2,
#  'RochaErik': 2,
#  'RC1844': 2,
#  'torch2424': 1,
#  'Djameleddine21': 2,
#  'eWebWork': 5,
#  'hyli666': 2,
#  'KNeeraj038': 1,
#  'SahilNagpure07': 1,
#  'akachler': 1,
#  'Pushkar1853': 2,
#  'vyasriday': 4,
#  'shsaaad': 1,
#  'wickkiey': 2,
#  'angular-moon': 10,
#  'mictebbe': 1,
#  'luanzhong': 1,
#  'M1thrandirZ': 1,
#  'Brkozshn': 1,
#  'Lay0us1': 3,
#  'pnads': 3,
#  'davidjpella': 1,
#  'Leorek': 1,
#  'nicoprocessor': 6,
#  'emillime': 1,
#  'fengxiqinhu': 2,
#  'IsaacBreen': 1,
#  'viphak': 6,
#  'liuxiong332': 8,
#  'LWelsh': 1,
#  'tammysgibson41': 1,
#  'imzhaojiuhui': 1,
#  'SuperS0n1k': 1,
#  'SKempiak': 1,
#  'Dev1an': 1,
#  'carlrobert': 1,
#  'wangyuo1997': 1,
#  'gonnabea': 1,
#  'Felicia35': 2,
#  'ShaunShaw': 1,
#  'JetFault': 1,
#  'Smit271': 1,
#  'sankethpb': 2,
#  'sirfragles': 1,
#  'Felipesdeveloper': 1,
#  'gouzigege': 1,
#  'Roharui': 2,
#  'seeker815': 1,
#  'fy5220': 3,
#  'joebutler2': 1,
#  'missArthas': 1,
#  'delsiiin': 1,
#  'BLUECARVIN': 6,
#  'zwdcoder': 1,
#  'maxlamberti': 1,
#  'jmt330': 1,
#  'whaattupp': 9,
#  'grigM': 7,
#  'elibirov': 1,
#  'avulix': 1,
#  'labixiaowang': 1,
#  'No0HMX': 1,
#  'taehyoungjo': 4,
#  'dege88': 2,
#  'gfayette': 1,
#  'Jearyhao': 1,
#  'inckie': 5,
#  'Licoy': 4,
#  'gokul-krishna': 2,
#  'hakunamatata1997': 5,
#  'liuxinwei-hust': 1,
#  'kimsehwan96': 3,
#  'Musketeer-D': 1,
#  'hadolop': 4,
#  'takuya-andou': 1,
#  'ImGenis': 1,
#  'bittour': 1,
#  'hossein-jazayeri': 3,
#  'fukubaka0825': 1,
#  'turningfrog': 1,
#  'C-SonDragon': 1,
#  'rismoney': 1,
#  'YanchaoJia': 2,
#  'sanshiyayaya': 1,
#  'jacklmind': 1,
#  'nedimcanulusoy': 5,
#  'xanoni': 1,
#  'lilasaba': 3,
#  'zurikz': 1,
#  'meteyildirim': 2,
#  'tyeon95': 3,
#  '1541186244': 1,
#  'Jiawei-Tang-0820': 1,
#  'jiajunli21': 1,
#  'oneaxxall': 2,
#  'dhammo2': 1,
#  'mogiwara': 6,
#  'TimothyL96': 3,
#  'homeBoby': 1,
#  'Guru0593': 1,
#  '0Master': 2,
#  'petergergics': 1,
#  'mabramkin': 1,
#  'bigsea00001': 2,
#  'peeintostorm': 1,
#  'sungam94': 2,
#  'Neeoko16': 1,
#  'MaxweIISmith': 1,
#  'binarytree': 3,
#  'anyuray': 4,
#  'puddinord': 4,
#  'ggck43': 3,
#  'franklioxygen': 4,
#  'xiaozzk': 1,
#  'robert-s-lee': 1,
#  'jiangming956': 1,
#  'dtoqueiro': 1,
#  'alealv': 1,
#  'hanchenyao': 2,
#  'goneplaid': 2,
#  'dkarmon': 1,
#  'JinglingChen': 1,
#  'aussage': 1,
#  'ygihjsg1': 3,
#  'todb-r7': 1,
#  'karpitsky': 1,
#  'dopeyidea': 1,
#  'jittya': 1,
#  'BenzHuang': 1,
#  'andris9': 2,
#  'Qiniiii': 1,
#  'audio-lge87': 1,
#  'longhua': 1,
#  'ptonlix': 1,
#  'firezym': 3,
#  'Jihongliang': 1,
#  'bosaidong': 1,
#  'wusx00': 1,
#  'm-khademloo': 1,
#  'HackingHackers': 4,
#  'robertkellermann': 1,
#  'flanchegong': 2,
#  'f123888': 1,
#  'aozen': 1,
#  'dayAlone': 1,
#  'paotec22': 1,
#  'TerryHu': 1,
#  'gautrr': 1,
#  'Berdi123': 2,
#  'Alanford10': 2,
#  'damianpandolfi': 3,
#  'skratchdot': 3,
#  'Yifan108': 1,
#  'Plankton555': 1,
#  'astronoka': 2,
#  'Muchen-W': 2,
#  'jpg-gamepad': 2,
#  'look-sun': 2,
#  'huhu42': 1,
#  'gmenegatti': 8,
#  'vereon': 1,
#  'itaicaspi': 2,
#  'dooonabe': 1,
#  'chambored': 1,
#  'cosmoquester': 1,
#  'Neal917': 1,
#  'Hongbusi': 1,
#  'BROranger': 2,
#  'tuffylock': 1,
#  'EdricHemsworth': 1,
#  'tyinweb': 1,
#  'bahadirumutiscimen': 5,
#  'Amazeryogo': 1,
#  'danialbarghi': 1,
#  'XinyiLiu577086410': 1,
#  'SantiagoMerlo': 1,
#  'skago': 1,
#  'ptrself': 1,
#  'THEDARKNINJA': 1,
#  'netroadd': 1,
#  'arthursun2005': 1,
#  'dradu': 4,
#  'airsimon23': 4,
#  'stlala25': 1,
#  'CrossStyle': 3,
#  'MaxBellc': 1,
#  'zyang10github': 1,
#  'papayazm': 2,
#  'Ranjit246': 2,
#  'muzig': 3,
#  'nallath': 1,
#  'fperget': 1,
#  'xueyf22': 3,
#  'andrzej44556': 1,
#  'SebastienDes': 1,
#  'XpecialD': 1,
#  'YuvaSuthar': 1,
#  'jonlu0602': 3,
#  'mkumar10': 2,
#  'DavidykZhao': 2,
#  'cubistvowels': 1,
#  'lukegao11': 1,
#  'sanya567': 1,
#  'joelibaceta': 6,
#  'jefft255': 2,
#  'nhtlongcs': 10,
#  'Bluebull7': 3,
#  'thepavangollapalli-zz': 1,
#  'zhanghuicuc': 3,
#  'anlek': 1,
#  'dennishoyer': 1,
#  'gasvn': 2,
#  'sjbird331': 4,
#  'ugurozsahin': 1,
#  'lamboy': 1,
#  'jasza80': 1,
#  'GabrieliusKazakevicius': 1,
#  'termitepreston': 1,
#  'dengguoxin': 1,
#  'raspi': 9,
#  'justforxm': 1,
#  'niall-twomey': 1,
#  'aziule': 6,
#  'bobo59': 2,
#  'avemax': 4,
#  'God-Dead': 1,
#  'luigilomasto': 1,
#  'iztkm': 2,
#  'wongstarry': 1,
#  'bagoesz21': 1,
#  'overdose425': 1,
#  'druagoon': 1,
#  'finnkauski': 4,
#  'junkham': 1,
#  'ErwinCheung': 1,
#  'huangxingx': 1,
#  'blokhin': 4,
#  'Fryke': 1,
#  'hu7433438': 1,
#  'Elaineyex': 2,
#  'dengrui-64': 1,
#  'seasonjj': 2,
#  'George-078': 2,
#  'avan-sh': 11,
#  'nhanpotter': 1,
#  'chihyuwang': 4,
#  'guomxin': 1,
#  'wcrasta': 1,
#  'BetterDay-L': 1,
#  'hoanghng': 1,
#  'bnulxe': 5,
#  'vishuv': 4,
#  'wasmir': 1,
#  'Spartinus': 1,
#  'colt005': 1,
#  'lwb0818': 1,
#  'iw-ic': 1,
#  'muktharshaik': 1,
#  'poteirard': 1,
#  'pikachupao': 1,
#  'neerajbansal': 1,
#  'branBeckett': 3,
#  'edwardpark': 1,
#  'HiPipilu': 1,
#  'pymooner': 3,
#  'gulcu': 6,
#  'attrung': 1,
#  'kabuto-png': 1,
#  'jeanluciradukunda': 1,
#  'abonec': 1,
#  'Diaoxiaozhang': 4,
#  'nickbear': 2,
#  'seanbae': 5,
#  'g3711': 3,
#  'vikramlucky': 1,
#  'nobillowseagit': 14,
#  'begend': 2,
#  'MikeKejinLee': 1,
#  'scottli139': 2,
#  'CodeDogandCat': 2,
#  'dredresan': 1,
#  'xingfukun': 1,
#  'binwangh': 1,
#  'blackpost38': 1,
#  'linbei114': 1,
#  'Okery': 2,
#  'ZenTrade': 1,
#  'lingkawaii': 1,
#  'bailscodesstuff': 2,
#  'Nhuttz': 1,
#  'menna-Mahmoud': 1,
#  'Davidswa': 1,
#  'Shawn94': 1,
#  'BLACK-POPCORN': 1,
#  'Mac-King': 1,
#  'xchange': 1,
#  'TaoKai': 3,
#  'mikey9709': 1,
#  'Surfndez': 8,
#  'pitaWu': 10,
#  'mhyamani': 1,
#  'Weber-Comm': 1,
#  'lrghust': 3,
#  'Iv4n550': 1,
#  'socaty': 1,
#  'Thang30': 3,
#  'Yian-lin': 1,
#  'kendfss': 1,
#  'kristpapadopoulos': 6,
#  'youhouhou': 1,
#  'opratrx': 1,
#  'Sunshine-hero': 1,
#  'haloless': 2,
#  'xfzephyr': 1,
#  'mv9k': 3,
#  'ryulurala': 1,
#  'chaycarnell': 1,
#  'rogercotrina': 1,
#  'fwping': 1,
#  'chaitanyahebbal': 9,
#  'alexisgra': 1,
#  'hoyun0702': 1,
#  'Jones-SnowCone': 1,
#  'Confirm4Crit': 1,
#  'FluxB': 1,
#  'tomyoung903': 1,
#  'hxstdio': 1,
#  'shyamStarwalt': 1,
#  'dunef-com': 1,
#  'Ragnarok540': 3,
#  'ClementHuber': 1,
#  'GoldenBaozi': 1,
#  'ColaLing': 4,
#  'ashup0214': 1,
#  'iib0011': 2,
#  'NoneDebug': 1,
#  'xz404': 1,
#  'henry0475': 3,
#  'DominicWoozy': 1,
#  'Esther-hong': 1,
#  'Daniel-Kant': 1,
#  'alessiojpg': 1,
#  'Anki-z': 1,
#  'danroshko': 2,
#  '6armyflag6': 5,
#  'sowcow': 2,
#  'kamadocat': 1,
#  'Quexint': 9,
#  'gerrylin': 6,
#  'jessicajones174': 1,
#  'srjbishtji': 1,
#  'gdemirezen': 1,
#  'bhdzllr': 1,
#  'dbalabka': 27,
#  'manoj147': 1,
#  'numeroespaciotiempo': 1,
#  'Hack06': 1,
#  'anna-jov': 1,
#  'anglinb': 5,
#  'Omar12': 4,
#  'rogerfydp': 1,
#  'paulf98': 1,
#  'fengshgx': 1,
#  'KatsuragiCSL': 1,
#  'danielredwood': 1,
#  'JackyMdCrdj': 3,
#  'andre-karrlein': 1,
#  'MrYogurt': 1,
#  'realyin': 1,
#  'abcisa': 1,
#  'cpdu': 3,
#  'thekapadia': 1,
#  'jakubpetrik': 1,
#  'Shaa2U': 1,
#  'jamiebg1': 1,
#  'LGHTNNG': 1,
#  'nk1710210': 2,
#  'jbroadus': 1,
#  'ZijianHu-polyu': 1,
#  'ligonzheng': 1,
#  'Apoclypt1c': 1,
#  'qfdxyt': 1,
#  'lisphacker': 1,
#  'daniel31x13': 4,
#  'Talha-T': 1,
#  'fivehanz': 5,
#  'DerekRiver': 1,
#  'zxc99039': 1,
#  'lin-hu': 1,
#  'Klasnov': 1,
#  'jiqinkai': 1,
#  'wingedseraph': 1,
#  'junaruga': 1,
#  'wenjli123': 1,
#  'Roll920': 2,
#  'wleii': 2,
#  'SadriShehu': 1,
#  'danielpgross': 1,
#  'sillihkram': 1,
#  'ifkite': 3,
#  'varunchodha': 1,
#  'JoanSF': 6,
#  'SoulDee': 2,
#  'vibster': 2,
#  'hulittlewhite': 1,
#  'NFEL': 1,
#  'Anacoder1': 9,
#  'ivlucks': 2,
#  'mateuszzadorski': 1,
#  'neilmadsen': 1,
#  'elepht': 1,
#  'Miyayx': 1,
#  'GentaK2018': 1,
#  'zhanghaocs': 1,
#  'scorego': 2,
#  'Marciniec': 2,
#  'startung': 1,
#  'Kaorthraya': 1,
#  'snakex77': 1,
#  'datdev2409': 1,
#  'ribesstefano': 1,
#  'MiguelFreire': 3,
#  'georgenardes': 1,
#  'netpoetica': 1,
#  'SikaAntler': 1,
#  'DineshDevPandey': 9,
#  'diegotorrent': 1,
#  'A-Alex27': 1,
#  'facat': 1,
#  'kaijchen': 2,
#  'Kartiku': 7,
#  'RyanFu': 2,
#  'NetraInamdar': 1,
#  'nicomts': 1,
#  'drishanarora': 1,
#  'Geseti': 1,
#  'donghao95': 1,
#  'jandykwan': 1,
#  'saymynameww': 1,
#  'Recardo-M': 1,
#  'djshaji': 2,
#  'ramyagokulp': 1,
#  'abc66099': 1,
#  'kelvin52901': 2,
#  'marufshidiq': 3,
#  'yxwang-10': 2,
#  'kanchan700': 1,
#  'mpumezogqoboka': 1,
#  'SigmazKoray': 1,
#  'Hamza-H10': 1,
#  'Kishore-Anthony': 1,
#  'gsrai': 1,
#  'KhalidBrinto': 2,
#  'MustafaCa': 1,
#  'kircal': 4,
#  'maomontes': 2,
#  'german-bortoli': 1,
#  'August-1997': 1,
#  'ahmadalfy': 1,
#  'ds-giao': 1,
#  'imAliAsad': 1,
#  'OneAuLeaf': 1,
#  'Denisevi4': 3,
#  'anujgupta82': 3,
#  'heiybb': 1,
#  'bayuedekui': 1,
#  'rabbitkiller-dev': 1,
#  'Sarami67': 1,
#  'Shoooske': 1,
#  'fduMark': 2,
#  'wdkeyzer': 1,
#  'squidass': 3,
#  'JnCrMx': 2,
#  'chia-labradorsystems': 1,
#  'michalmaksymow': 1,
#  'bxz9200': 1,
#  'limeya': 1,
#  'jolob5l': 2,
#  'erxiaoouba': 1,
#  'imperorrp': 1,
#  'mafamily2496': 3,
#  'luogel': 1,
#  're2panda': 1,
#  'xixizxx': 1,
#  'mcdonalda1993': 1,
#  'martingitehi': 1,
#  'hd-lee': 1,
#  'SeungBack': 3,
#  'clive2000': 5,
#  'lostpaddle': 1,
#  'weizaixl': 4,
#  'zhangshengfei0222': 1,
#  'happyemoji': 2,
#  'subject-nil': 7,
#  'lucaskalves': 1,
#  'nihilityer': 1,
#  'TheoDeann': 1,
#  'M-H-2020': 1,
#  'victorazevedo': 1,
#  'Vicente015': 1,
#  'umutcakan': 1,
#  'nhgowtham': 1,
#  'RouderSky': 5,
#  'anielcrz': 2,
#  'n7best': 4,
#  'vski5': 3,
#  'mateusfrmacedo': 1,
#  'LiuChunxiu': 2,
#  'Cmajor98': 1,
#  'wanghaohw': 1,
#  'MedAliMimouni': 1,
#  'modouG': 4,
#  'johnycage': 2,
#  'wchaowu': 2,
#  'Shikhas': 4,
#  'hungleba': 1,
#  'halit-vural': 2,
#  'mshirvani624': 1,
#  'erenche': 1,
#  'Fusica': 6,
#  'Zappandy': 5,
#  'storesund': 4,
#  'mschneider82': 1,
#  'ZackHodari': 10,
#  'kiranshanmugam2001': 1,
#  'THZdyjy': 4,
#  'kennethlaqui': 1,
#  'dengfuqiu': 2,
#  'GoonJin': 1,
#  'spoon1022': 1,
#  'matthias-maier': 1,
#  'yeeeeee0724': 1,
#  'mystreamer': 4,
#  'Dimantarian': 1,
#  'Jachowski': 1,
#  'ratn0101': 1,
#  'luhavis': 8,
#  'theotherone702Hi': 2,
#  'duruiting': 1,
#  'KryneChen': 8,
#  'rese1f': 7,
#  'kobeHub': 3,
#  'everestwinter': 1,
#  'Boo1Dr': 1,
#  'JonathanCMitchell': 1,
#  'LJacki': 2,
#  'Enki-Zhang': 1,
#  'nawar29': 1,
#  'andyquint': 1,
#  'SykChw': 3,
#  'gmendes': 2,
#  'yulongpo': 5,
#  'igorimagine': 1,
#  'bushishamate': 1,
#  'scopophobic': 3,
#  'r2d2m': 2,
#  'yuanzhoulvpi2017': 3,
#  'Lillard01': 2,
#  'andyqee': 2,
#  'Bumblefo': 1,
#  'legends2k': 1,
#  'aolaideng': 1,
#  'jf-eirinha': 2,
#  'zjaweds': 1,
#  'clark11': 1,
#  'auryglover': 1,
#  'bluekingdom': 2,
#  'AndroidXuexizhe': 1,
#  'WOOSIEUN': 1,
#  'OctopusZ': 1,
#  'Li-Yunshuang': 1,
#  'm13601594065': 2,
#  'xoox': 5,
#  'felipek': 7,
#  'Tracey-ZP': 1,
#  'kevinclementdnvgl': 1,
#  'driverding': 1,
#  'JLidia': 2,
#  'gaetan000': 1,
#  'PeakMic': 2,
#  '2naff': 1,
#  'yuguorui': 3,
#  'gy15901580825': 1,
#  'khlling': 1,
#  'Evolutionary-Intelligence': 3,
#  'Genius3838': 1,
#  'derkeller': 1,
#  'yuanxi7015': 1,
#  'ray4585': 2,
#  'shanefully-done': 1,
#  'xzlgw': 1,
#  '1130419': 1,
#  'mystique': 1,
#  'Kcazer': 1,
#  'EugeneZheltetskiy': 1,
#  'puneet29': 1,
#  'wshaoxin': 1,
#  'andreasmattas': 1,
#  'robertracz': 2,
#  'PengJoy1106': 1,
#  'zhenweibaobei': 2,
#  'hurecue': 1,
#  'HarshBedmutha': 1,
#  '0x1': 3,
#  'mumin-khan': 1,
#  'neotechnical': 1,
#  'weironghuang31': 1,
#  'agore': 1,
#  'ajzaff': 1,
#  'feizy': 2,
#  'mannumusyoka': 1,
#  'left-wall': 1,
#  'gunduru': 3,
#  'XianjiangLi': 1,
#  'luiszugasti': 2,
#  'FloVnst': 1,
#  'zagorastyle': 1,
#  'pengyuenhao': 1,
#  'PPXGS': 1,
#  'xiaoding': 2,
#  'amin-henteti': 1,
#  'bcc0421': 1,
#  'dagang2017': 2,
#  'francescomannarino': 1,
#  'imagelife': 1,
#  'TimTheOverlord': 2,
#  'Narayan-Dhingra': 4,
#  'qinghai5060': 3,
#  'guilhermecostac': 1,
#  'cloudboy1975': 1,
#  'amalhanaja': 2,
#  'sleventyeight': 1,
#  'jishin86': 5,
#  'trusovandrey1': 3,
#  'zeyneepsozen': 1,
#  'Markus-ipse': 3,
#  'daalla': 1,
#  'cfei1919': 3,
#  'gimbir': 1,
#  'mayccc123': 1,
#  'jmbhughes': 5,
#  'qiang123': 2,
#  'dingo9': 2,
#  'hariangr': 1,
#  'mubingshen': 1,
#  'malangapapi': 1,
#  'Rcsuax': 3,
#  'soohanpark': 1,
#  'heathmills': 6,
#  'XuejiFang': 3,
#  'mohammadjahanipour': 2,
#  'Omnia-Elmoazen': 1,
#  'scorpio-94': 1,
#  'LeviZell': 2,
#  'Tbushnaq': 1,
#  'rdalmagro': 1,
#  'bell-one': 1,
#  'XiangyuLiuSEU': 2,
#  'jasonchaffee': 1,
#  'baosan2': 1,
#  'shoffmeister': 2,
#  'Renewetubongbanua': 1,
#  'mengmingliang': 1,
#  'azarashi0519': 1,
#  'nabinked': 1,
#  'preetjdp': 1,
#  'Hona': 1,
#  'Stormtv': 1,
#  'kuwacom': 1,
#  'pfontana96': 1,
#  'crazywiden': 1,
#  'newebug': 1,
#  'yangjiayuGIT': 1,
#  'josephpconley': 1,
#  'AdrianMTZVazquez': 1,
#  'toxickrait': 2,
#  'upup179': 1,
#  'luohoufu': 1,
#  'antony-jr': 1,
#  'LYsnal': 1,
#  'fuwei199006': 1,
#  'Shelden-Thomas': 1,
#  'Phypyy': 1,
#  'rucoven': 1,
#  'nilsmagnus': 3,
#  'VirgilChen97': 2,
#  'svensvx': 1,
#  'MasanoriOnuki': 1,
#  'Quehry': 6,
#  'SergeevVladislav': 9,
#  'CocoFresh': 2,
#  'fangs311': 2,
#  'barisx': 1,
#  'abdellatif98-a': 1,
#  'justimchung': 1,
#  'dinxdays': 1,
#  'Vatsalya97': 1,
#  'moc44': 1,
#  'pavitrashah': 3,
#  'fun1355': 1,
#  'WordZzzz': 4,
#  'lucadibello': 2,
#  'PGCharlesFC': 1,
#  'wh-isper': 1,
#  'gauravpradeep': 1,
#  'icaikun': 1,
#  'guaguatanqi': 1,
#  'zyswyq': 1,
#  'ik5': 36,
#  'jamesmtexas': 1,
#  'pblan': 1,
#  'ubednama': 1,
#  'huandzh': 3,
#  'bhavyaverma1': 3,
#  'dhruvadevireddy': 1,
#  'johnkapson': 6,
#  'RefrainTC': 10,
#  'Chegevarich': 1,
#  'davidycliao': 5,
#  '7kg': 1,
#  'orzzzl': 1,
#  'YoungJian12': 1,
#  'milliyx': 1,
#  'lei-mu': 1,
#  'PigeonXianxian': 1,
#  'dannas': 2,
#  'brrrrrrm': 1,
#  'Ashley-ee': 2,
#  'rubenrobot': 1,
#  'motilyfor': 1,
#  'GuyChrome18': 1,
#  'NISHCHITHA-C': 1,
#  'AbeEstrada': 1,
#  'grcevski': 2,
#  'yennth': 1,
#  'zcy924': 1,
#  'xieqiaowanghs': 1,
#  'YiyuanLei': 1,
#  'looneyd-rohit': 1,
#  'muhmp': 1,
#  'kevinqualters': 1,
#  'ataa': 3,
#  'PatrickHeiisen': 1,
#  'atmimran': 1,
#  'skywalker1991': 1,
#  'hjbiao09': 10,
#  'brnlopes': 1,
#  'chen1u': 3,
#  'hqe18': 1,
#  'aadyabansal': 1,
#  'Hilbert-Anjou': 1,
#  'christianemmert': 1,
#  'jfmercillemetro': 1,
#  'mjferh': 1,
#  'dzu181': 2,
#  'Modelizer': 1,
#  'cmckni3': 1,
#  'JasenZ2000': 1,
#  'Nirosun': 1,
#  'mxxu': 4,
#  'tawfiqbhyry': 1,
#  'vanoudh': 1,
#  'andrebritto': 1,
#  'Winterstorm-j': 1,
#  'DBUG-DBUG': 5,
#  'Kipsora': 11,
#  'gabrielsolarg': 2,
#  'kanvesh': 1,
#  'ccdodo': 1,
#  'Ray941216': 1,
#  'Mikkou': 1,
#  'KINGH242': 1,
#  'mahvash-siavashpour': 1,
#  'titu1994': 16,
#  'yoheikikuta': 1,
#  'gomigoxx': 1,
#  'lotuny': 1,
#  'wilbur-yu': 10,
#  'ClemensHoerl': 1,
#  'vkhoi': 3,
#  'QinYuGen': 4,
#  'hyeonjungko': 1,
#  'zhongyl0430': 1,
#  'a776058959': 1,
#  'NicholasKimuli': 1,
#  'saksham12': 2,
#  'sylvainlebeux': 1,
#  'shook2012': 4,
#  'chaizhongming': 1,
#  'RhythmDim': 1,
#  'Swaraj-Parida': 1,
#  'SamOyeAH': 3,
#  'knowrat': 1,
#  'alexcheng1982': 1,
#  'SwaggyYan': 2,
#  'ecrider': 5,
#  'jp00p': 1,
#  'listerineh': 1,
#  'xueqiut': 1,
#  'dagingehelgoy': 2,
#  'Liujqlbs': 1,
#  'iperformance': 3,
#  'CaptainRay1993': 5,
#  'peach719': 1,
#  'Hyperion-shuo': 5,
#  'MetaYu': 1,
#  'popfalushi': 2,
#  'YmirSs': 1,
#  'changwoolab': 4,
#  'dan-coates': 1,
#  'haewoon': 1,
#  'hunkyu': 1,
#  'naveenmishra': 1,
#  'Geoyk96': 1,
#  's': 4,
#  'ben2d': 1,
#  'minemcdull': 1,
#  'di-lab-stack': 1,
#  'systemkrash': 1,
#  'danielneis': 1,
#  'ChangWinde': 6,
#  'gcaggia': 3,
#  'LzgsGithub': 2,
#  'MikaelGrowthEngineer': 2,
#  'IBabych': 2,
#  'ciciramsey': 1,
#  'fdnavarropecci': 5,
#  'sally': 2,
#  'ein-ich': 2,
#  'gavindewhirst': 1,
#  'kashiahmed': 1,
#  'hayakawa': 1,
#  'candiii-lin': 3,
#  'drsmith48': 3,
#  'Shelob9': 2,
#  'debido666': 1,
#  'D1maD1m0nd': 1,
#  'kevintully': 1,
#  'sibukixxx': 1,
#  'AmazingLun15': 1,
#  'sobolevdmitry': 1,
#  'HUANGNOT': 4,
#  'naveenspace7': 4,
#  'GLaTurret': 1,
#  'AnoKno': 1,
#  'DevWizardDan': 1,
#  'altiplanogao': 1,
#  'pacren': 1,
#  'xoniks': 1,
#  'eladendorf': 2,
#  'Fcantalice': 1,
#  'Mejikan': 1,
#  'happychain': 1,
#  'rexueyihen': 2,
#  'wmwql': 1,
#  'TakahiRoyte': 1,
#  'songsong-sunny': 1,
#  'Cath-kb': 1,
#  'nhanmn': 1,
#  'wenpengfei': 5,
#  'Wyatt-Stanke': 18,
#  'PlayByMyself': 2,
#  'david-barrios': 1,
#  'zollum': 1,
#  'Jokingpoet': 1,
#  'b-zhou': 1,
#  'nullscc': 2,
#  'divkrash': 2,
#  'FishSpringmu': 1,
#  'ykob': 1,
#  'flying-ringtail': 1,
#  'ismaelmcosta': 2,
#  'haggen': 1,
#  'choec0130': 1,
#  'alexcode16': 1,
#  'kartik0025': 1,
#  'ayeganov': 13,
#  'Willjay5991': 1,
#  '744211': 1,
#  'frankwwu': 6,
#  'Wuguagnjie': 2,
#  'codetalks-new': 1,
#  'ElmurodovJavohir': 1,
#  'KurtVelasco': 1,
#  'Loner291999': 2,
#  'yahyakharrazi': 2,
#  'Abellegese': 1,
#  'flaxh': 1,
#  'rongzhou': 23,
#  'jmpcosta': 1,
#  'AndreiXYZ': 4,
#  'rbozan': 4,
#  'jsenny': 1,
#  'anjinde': 1,
#  'filipepiresg': 1,
#  'EleVenPerfect': 1,
#  'garyblankenship': 9,
#  'guigui258v5': 1,
#  'ajy123': 1,
#  'm0j1k4b3': 1,
#  'kimbugp': 2,
#  'Spandan7724': 1,
#  'ChengYaofeng': 7,
#  'ferluchin': 1,
#  'jp555soul': 3,
#  'Lazybones3': 3,
#  'exhesham': 1,
#  'michaelomm': 1,
#  'jomathin': 1,
#  'Darcy0913': 1,
#  'kylineos': 1,
#  'Vi-Kin': 1,
#  'eagleHovering': 1,
#  'XYDong': 1,
#  'Ferdzz': 1,
#  'tdp2110': 5,
#  'donglin1608': 1,
#  'fenglin681': 1,
#  'ptkien2023': 1,
#  'NotUrGirl': 1,
#  'davnati': 2,
#  'samchd13': 2,
#  'toonvdijck': 1,
#  'Randek': 1,
#  'Dune-Z': 3,
#  'aisis': 1,
#  'vanslambrouckd': 1,
#  'billwen': 1,
#  'viv1729': 2,
#  'bellsmarket': 1,
#  'jakenathanson': 1,
#  'IndowK': 1,
#  'hyace': 2,
#  'candrwow': 8,
#  'EduFdezSoy': 3,
#  'snowkylin': 5,
#  'remiliyaScarlet': 1,
#  'andriiginting': 1,
#  'KaQiNuo': 1,
#  'liegqing': 1,
#  'rfkdali': 1,
#  'djtuananh20': 1,
#  'RistoAle97': 2,
#  '3205914485': 1,
#  'EricGT': 5,
#  'linxi20': 2,
#  'stuartlee165': 1,
#  'jrdi': 2,
#  'adityaladwa': 2,
#  'akontra': 21,
#  'VijayrajS': 1,
#  'linhkakashi': 1,
#  'abhishekthakur0': 2,
#  'mohapsat': 4,
#  'gorayni': 1,
#  'Edznux': 1,
#  'huguangju': 1,
#  'sanjaybhansali108': 1,
#  'vtandroid': 7,
#  'alejandro0619': 1,
#  'spades-k': 2,
#  'Ahmed-AmineHomman': 1,
#  'zzqCindy': 2,
#  'bronzitte': 1,
#  'mstritt': 1,
#  'zhangxiaoqiang7': 1,
#  'jkgjhfghdgfscv': 1,
#  'processnull': 2,
#  'YanWuGit': 1,
#  'dongxiaoxing': 1,
#  'igiffard': 1,
#  'artint-liu': 2,
#  'suyu-dins': 1,
#  'wmhqnyh': 2,
#  ...}

# %%
dict(degY)
# Out:
# {'100-Days-Of-ML-Code.json': 40000,
#  'd2l-zh.json': 40000,
#  'pytorch.json': 40000,
#  'applied-ml.json': 26038,
#  'DeepSpeech.json': 24389,
#  'awesome-deep-learning-papers.json': 25155,
#  'stanford_alpaca.json': 28882,
#  'faceswap.json': 40000,
#  'GFPGAN.json': 34704,
#  'handson-ml.json': 25093,
#  'keras.json': 40000,
#  'data-science-ipython-notebooks.json': 26534,
#  'MockingBird.json': 33960,
#  'yolov5.json': 40000,
#  'spleeter.json': 25008,
#  'caffe.json': 33885,
#  'transformers.json': 40000,
#  'awesome-datascience.json': 23837,
#  'pytorch-tutorial.json': 29185,
#  'ColossalAI.json': 37997,
#  'TTS.json': 29709,
#  'ML-From-Scratch.json': 23217,
#  'ultralytics.json': 23422,
#  'gradio.json': 29257,
#  'so-vits-svc.json': 24178,
#  'tesseract.js.json': 33697,
#  'fastai.json': 25666,
#  'annotated_deep_learning_paper_implementations.json': 40000,
#  'stable-diffusion-webui.json': 40000,
#  'openpose.json': 29969,
#  'machine-learning-for-software-engineers.json': 27770,
#  'AI-Expert-Roadmap.json': 28498,
#  'mediapipe.json': 25609,
#  'tensorflow.json': 40000,
#  'Made-With-ML.json': 35812,
#  'cs-video-courses.json': 40000,
#  'DeepFaceLab.json': 40000,
#  'DeepSpeed.json': 32960,
#  'pytorch-lightning.json': 27028,
#  'Real-Time-Voice-Cloning.json': 40000,
#  'TensorFlow-Examples.json': 40000,
#  'streamlit.json': 32020,
#  'Prompt-Engineering-Guide.json': 40000,
#  'AI-For-Beginners.json': 31515,
#  'spaCy.json': 28842,
#  'ray.json': 31368,
#  'netron.json': 26262,
#  'opencv.json': 40000,
#  'Deep-Learning-Papers-Reading-Roadmap.json': 37409,
#  'paper-reading.json': 24366}

# %%
Counter(dict(degX).values())  # distribution of the number of users starred the repos
# Out:
# Counter({1: 512852,
#          2: 132445,
#          8: 5871,
#          4: 30509,
#          3: 57388,
#          5: 18831,
#          6: 12128,
#          7: 8224,
#          9: 4394,
#          23: 223,
#          28: 105,
#          12: 1981,
#          10: 3238,
#          11: 2504,
#          13: 1497,
#          14: 1211,
#          19: 452,
#          18: 540,
#          16: 827,
#          26: 127,
#          15: 1076,
#          17: 671,
#          20: 352,
#          34: 35,
#          39: 20,
#          30: 77,
#          41: 13,
#          27: 113,
#          32: 55,
#          25: 170,
#          21: 306,
#          22: 245,
#          24: 183,
#          31: 65,
#          37: 27,
#          33: 44,
#          29: 86,
#          46: 5,
#          38: 24,
#          36: 25,
#          35: 40,
#          50: 3,
#          45: 5,
#          40: 14,
#          44: 8,
#          42: 12,
#          43: 4,
#          48: 3,
#          47: 2})
